# %%
import os
import time
import requests
from pprint import pprint
from bs4 import BeautifulSoup

path = 'D:/coding/leeyeonjun85/test'
os.chdir(path)
print(f"✅ 현재 위치 : {os.getcwd()}")

# Git Info
GIT_NAME = "leeyeonjun85"
GIT_EMAIL = "leeyeonjun85@gmail.com"
GIT_TOKEN = "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"
GIT_REPO = "leeyeonjun85"

# D:/coding/leeyeonjun85/
if os.path.isdir(path):
  print(f"""✅ {os.getcwd()}""")
else:
  print(f"""⛔ {os.getcwd()}""")

GIT_PATH = f"https://{GIT_TOKEN}@github.com/{GIT_NAME}/{GIT_REPO}.git"
GIT_PATH
# Out:
# ✅ 현재 위치 : D:\coding\leeyeonjun85\test
# ✅ D:\coding\leeyeonjun85\test
# 'https://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@github.com/leeyeonjun85/leeyeonjun85.git'

# %%
f = open("test.txt", 'w')
for i in range(1, 5):
    data = f"Line is {i}\n"
    f.write(data)
f.close()

for i in range(0, 10):
    data = f"Line is {i}\n"
    f = open("test.txt", 'w')
    f.write(data)
    f.close()
    # !git add .
    # !git commit -m "Update"
    # !git push
    time.sleep(1)
# Out:
# warning: in the working copy of 'test/git_colab.ipynb', LF will be replaced by CRLF the next time Git touches it
# [main 02517bb] Update
#  2 files changed, 2 insertions(+), 5 deletions(-)
# remote: Resolving deltas:   0% (0/3)
# remote: Resolving deltas:  33% (1/3)
# remote: Resolving deltas:  66% (2/3)
# remote: Resolving deltas: 100% (3/3)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/leeyeonjun85/leeyeonjun85.git
#    b04c3ec..02517bb  main -> main
# [main 8a2d72f] Update
#  1 file changed, 1 insertion(+), 1 deletion(-)
# remote: Resolving deltas:   0% (0/2)
# remote: Resolving deltas:  50% (1/2)
# remote: Resolving deltas: 100% (2/2)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/leeyeonjun85/leeyeonjun85.git
#    02517bb..8a2d72f  main -> main
# [main e3222c3] Update
#  1 file changed, 1 insertion(+), 1 deletion(-)
# remote: Resolving deltas:   0% (0/2)
# remote: Resolving deltas:  50% (1/2)
# remote: Resolving deltas: 100% (2/2)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/leeyeonjun85/leeyeonjun85.git
#    8a2d72f..e3222c3  main -> main
# [main 8eed37b] Update
#  1 file changed, 1 insertion(+), 1 deletion(-)
# remote: Resolving deltas:   0% (0/2)
# remote: Resolving deltas:  50% (1/2)
# remote: Resolving deltas: 100% (2/2)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/leeyeonjun85/leeyeonjun85.git
#    e3222c3..8eed37b  main -> main
# [main 371cb64] Update
#  1 file changed, 1 insertion(+), 1 deletion(-)
# remote: Resolving deltas:   0% (0/2)
# remote: Resolving deltas:  50% (1/2)
# remote: Resolving deltas: 100% (2/2)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/leeyeonjun85/leeyeonjun85.git
#    8eed37b..371cb64  main -> main
# [main ff0e628] Update
#  1 file changed, 1 insertion(+), 1 deletion(-)
# remote: Resolving deltas:   0% (0/2)
# remote: Resolving deltas:  50% (1/2)
# remote: Resolving deltas: 100% (2/2)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/leeyeonjun85/leeyeonjun85.git
#    371cb64..ff0e628  main -> main
# [main d4c8886] Update
#  1 file changed, 1 insertion(+), 1 deletion(-)
# remote: Resolving deltas:   0% (0/2)
# remote: Resolving deltas:  50% (1/2)
# remote: Resolving deltas: 100% (2/2)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/leeyeonjun85/leeyeonjun85.git
#    ff0e628..d4c8886  main -> main
# [main 97aee64] Update
#  1 file changed, 1 insertion(+), 1 deletion(-)
# remote: Resolving deltas:   0% (0/2)
# remote: Resolving deltas:  50% (1/2)
# remote: Resolving deltas: 100% (2/2)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To https://github.com/leeyeonjun85/leeyeonjun85.git
#    d4c8886..97aee64  main -> main
# [main 0f9f893] Update
#  1 file changed, 1 insertion(+), 1 deletion(-)
