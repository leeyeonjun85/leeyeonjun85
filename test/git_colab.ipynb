# %%
import os
import time
import requests
from pprint import pprint
from bs4 import BeautifulSoup

path = 'D:/coding/leeyeonjun85/test'
os.chdir(path)
print(f"✅ 현재 위치 : {os.getcwd()}")

# Git Info
GIT_NAME = "leeyeonjun85"
GIT_EMAIL = "leeyeonjun85@gmail.com"
GIT_TOKEN = "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"
GIT_REPO = "leeyeonjun85"

# D:/coding/leeyeonjun85/
if os.path.isdir(path):
  print(f"""✅ {os.getcwd()}""")
else:
  print(f"""⛔ {os.getcwd()}""")

GIT_PATH = f"https://{GIT_TOKEN}@github.com/{GIT_NAME}/{GIT_REPO}.git"
GIT_PATH
# Out:
# ✅ 현재 위치 : D:\coding\leeyeonjun85\test
# ✅ D:\coding\leeyeonjun85\test
# 'https://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@github.com/leeyeonjun85/leeyeonjun85.git'

# %%
f = open("test.txt", 'w')
for i in range(1, 5):
    data = f"Line is {i}\n"
    f.write(data)
f.close()

for i in range(0, 10):
    data = f"Line is {i}\n"
    f = open("test.txt", 'w')
    f.write(data)
    f.close()
    # !git add .
    # !git commit -m "Update"
    # !git push
    time.sleep(1)
# Out:
# ...
# [main 42cde95] Update
#  2 files changed, 2 insertions(+), 2 deletions(-)
# remote: Resolving deltas:   0% (0/3)
# remote: Resolving deltas:  33% (1/3)
# remote: Resolving deltas:  66% (2/3)
# remote: Resolving deltas: 100% (3/3)
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/leeyeonjun85/private.git
#    651c55f..42cde95  main -> main
# [main d18c530] Update
#  1 file changed, 1 insertion(+), 1 deletion(-)
# remote: Resolving deltas:   0% (0/1)
# remote: Resolving deltas: 100% (1/1)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/leeyeonjun85/private.git
#    42cde95..d18c530  main -> main
# [main 7dff738] Update
#  1 file changed, 1 insertion(+), 1 deletion(-)
# remote: Resolving deltas:   0% (0/1)
# remote: Resolving deltas: 100% (1/1)
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/leeyeonjun85/private.git
# ...

# %%
# !git config --global user.email 'leeyeonjun85@gmail.com'
# !git config --global user.name 'leeyeonjun85'

# %%
# !git add .

# %%
# !git commit -m 'test1'
# !git push

# %%
# 현재 디렉토리 보기
# %pwd

# %%
# 현재 디렉토리 파일 보기
# %ls

# %%
# github username
username = "leeyeonjun85"
# url to request
url = f"https://api.github.com/users/{username}"
# make the request and return the json
user_data = requests.get(url).json()
# pretty print JSON data
pprint(user_data)

# %%
# !pip install PyGithub

# %%
import base64
from github import Github
from pprint import pprint

# Github username
username = "leeyeonjun85"
# pygithub object
g = Github()
# get that user by username
user = g.get_user(username)

for repo in user.get_repos():
    print(repo)

# %%
def print_repo(repo):
    # repository full name
    print("Full name:", repo.full_name)
    # repository description
    print("Description:", repo.description)
    # the date of when the repo was created
    print("Date created:", repo.created_at)
    # the date of the last git push
    print("Date of last push:", repo.pushed_at)
    # home website (if available)
    print("Home Page:", repo.homepage)
    # programming language
    print("Language:", repo.language)
    # number of forks
    print("Number of forks:", repo.forks)
    # number of stars
    print("Number of stars:", repo.stargazers_count)
    print("-"*50)
    # repository content (files & directories)
    print("Contents:")
    for content in repo.get_contents(""):
        print(content)
    try:
        # repo license
        print("License:", base64.b64decode(repo.get_license().content.encode()).decode())
    except:
        pass

# %%
print_repo(user.get_repos()[3])

# %%
# iterate over all public repositories
for repo in user.get_repos():
    print_repo(repo)
    print("="*100)

# %%
username = git_user_name
password = git_token

# authenticate to github
g = Github(git_token)
# get the authenticated user
user = g.get_user()
for repo in user.get_repos():
    print_repo(repo)

# %%
repo = user.get_repos()[41]
repo.create_file("test3.txt", "test1", "test2", branch="main")

# %%
contents = repo.get_contents("test3.txt")
repo.delete_file(contents.path, "remove test3", contents.sha, branch="main")
